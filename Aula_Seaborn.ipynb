# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-usp/Python/blob/main/Aula_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Gráficos Seaborn

# %%
import pandas as pd
import seaborn as sns
dados = pd.read_csv('https://s3.amazonaws.com/caelum-online-public/1039-seaborn/material/tips.csv')
dados.head()
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %%
dados.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## Se as gorjetas maiores são acompanhadas com valor da conta maior

# %%
gorjeta = sns.scatterplot(x = 'total_bill', y = 'tip', data = dados)

# %%
dados['porcentagem'] = (dados['tip'] / dados['total_bill']).round(4)
dados
# Out:
#      total_bill   tip dessert   day    time  size  porcentagem
# 0         16.99  1.01      No   Sun  Dinner     2       0.0594
# 1         10.34  1.66      No   Sun  Dinner     3       0.1605
# 2         21.01  3.50      No   Sun  Dinner     3       0.1666
# 3         23.68  3.31      No   Sun  Dinner     2       0.1398
# 4         24.59  3.61      No   Sun  Dinner     4       0.1468
# ..          ...   ...     ...   ...     ...   ...          ...
# 239       29.03  5.92      No   Sat  Dinner     3       0.2039
# 240       27.18  2.00     Yes   Sat  Dinner     2       0.0736
# 241       22.67  2.00     Yes   Sat  Dinner     2       0.0882
# 242       17.82  1.75      No   Sat  Dinner     2       0.0982
# 243       18.78  3.00      No  Thur  Dinner     2       0.1597
#
# [244 rows x 7 columns]

# %%
porcentagem_da_conta = sns.scatterplot(x = 'total_bill', y = 'porcentagem', data = dados)

# %%
porcentagem_da_conta = sns.scatterplot(x = 'total_bill', y = 'porcentagem', data = dados)

# %%
porcentagem_da_conta = sns.lmplot(x = 'total_bill', y = 'porcentagem', data = dados)

# %% [markdown]
# Há uma tendência de que contas maiores pagam porcentagens menores

# %%
dados.head()
# Out:
#    total_bill   tip dessert  day    time  size  porcentagem
# 0       16.99  1.01      No  Sun  Dinner     2       0.0594
# 1       10.34  1.66      No  Sun  Dinner     3       0.1605
# 2       21.01  3.50      No  Sun  Dinner     3       0.1666
# 3       23.68  3.31      No  Sun  Dinner     2       0.1398
# 4       24.59  3.61      No  Sun  Dinner     4       0.1468

# %%
dados.describe()
# Out:
#        total_bill         tip        size  porcentagem
# count  244.000000  244.000000  244.000000   244.000000
# mean    19.785943    2.998279    2.569672     0.160798
# std      8.902412    1.383638    0.951100     0.061070
# min      3.070000    1.000000    1.000000     0.035600
# 25%     13.347500    2.000000    2.000000     0.129100
# 50%     17.795000    2.900000    2.000000     0.154750
# 75%     24.127500    3.562500    3.000000     0.191475
# max     50.810000   10.000000    6.000000     0.710300

# %%
filtro = (dados['dessert'] == "Yes") & (dados['total_bill'] > 30)
dados[filtro].describe()
#Somente os que consumiram sobremesa
# Out:
#        total_bill        tip       size  porcentagem
# count   17.000000  17.000000  17.000000    17.000000
# mean    37.131176   3.618235   3.117647     0.095341
# std      6.154016   1.939098   0.992620     0.037877
# min     30.060000   1.170000   2.000000     0.035600
# 25%     32.680000   3.000000   2.000000     0.074000
# 50%     34.650000   3.110000   3.000000     0.094500
# 75%     40.550000   3.680000   4.000000     0.106200
# max     50.810000  10.000000   5.000000     0.196800

# %%
filtro = (dados['dessert'] == "No") & (dados['total_bill'] > 30)
dados[filtro].describe()
# Out:
#        total_bill        tip       size  porcentagem
# count   15.000000  15.000000  15.000000    15.000000
# mean    37.617333   5.676667   4.133333     0.152307
# std      6.243397   1.321766   0.915475     0.030687
# min     30.400000   4.000000   3.000000     0.103800
# 25%     33.350000   5.000000   4.000000     0.134850
# 50%     35.260000   5.170000   4.000000     0.148400
# 75%     40.305000   6.350000   4.000000     0.184700
# max     48.330000   9.000000   6.000000     0.195300

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'dessert', data =dados)

# %%
sns.relplot(x = 'total_bill', y = 'porcentagem', hue = 'dessert', data =dados)

# %%
sns.catplot(x = 'dessert', y = 'tip', data = dados)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'dessert', col = 'time', data =dados)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', hue = 'dessert', col = 'time', data =dados)

# %%
sns.lmplot(x = 'total_bill', y = 'porcentagem', hue = 'dessert', col = 'time', data =dados)

# %%
sns.lmplot(x = 'total_bill', y = 'porcentagem', hue = 'day', col = 'day', data =dados)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', hue = 'dessert', col = 'day', data =dados)

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = dados)

# %%
sns.boxplot(x = 'day', y = 'total_bill', hue = 'dessert', data = dados)
